# %% [markdown]
# # Datu Vizualizācija un Ekstrapolēšana
#
# ## 1. Daļa - Pamata vizualizācija (Vieglākā)
#
# ⏱️ **Paredzētais laiks: ~20 minūtes**
#
# Šajā nodarbībā mēs izmantosim kafijas pārdošanas datus, lai iemācītos:
# - Ielādēt un apskatīt datus
# - Izveidot vienkāršas diagrammas
# - Analizēt tendences
#
# ### 📚 Noderīgas saites
# - [Pandas DataFrame pamati](https://pandas.pydata.org/docs/user_guide/10min.html) - 10 minūšu ievads
# - [Matplotlib grafiku galerija](https://matplotlib.org/stable/gallery/index.html) - piemēri ar kodu
# - [Python pamati](https://docs.python.org/3/tutorial/index.html) - ja nepieciešams atsvaidzināt
#
# ---

# %% [markdown]
# ### 1.1 Importējam nepieciešamās bibliotēkas
#
# Vispirms mums jāimportē Python bibliotēkas, kuras izmantosim:
# - `pandas` - datu apstrādei ([dokumentācija](https://pandas.pydata.org/docs/))
# - `matplotlib` - grafiku zīmēšanai ([dokumentācija](https://matplotlib.org/stable/))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Uzstādām, lai grafiki būtu skaistāki
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = [10, 6]

# %% [markdown]
# ### 1.2 Ielādējam datus
#
# Izmantojam `pandas` bibliotēku, lai ielādētu CSV failu.
#
# **Uzdevums:** Palaid šo šūnu, lai ielādētu datus!

# %%
# Ielādējam kafijas pārdošanas datus
df = pd.read_csv('../data/coffee_sales/index_1.csv')

# Pārvēršam datumu kolonnas uz datuma formātu
df['date'] = pd.to_datetime(df['date'])
df['datetime'] = pd.to_datetime(df['datetime'])

# Parādām pirmās 5 rindas
df.head()

# %% [markdown]
# ### 1.3 Iepazīstamies ar datiem
#
# Apskatīsim, kādas kolonnas ir mūsu datos un cik ierakstu ir kopā.

# %%
# Cik daudz ierakstu?
print(f"Kopā ierakstu: {len(df)}")
print(f"\nKolonnas:")
print(df.columns.tolist())
print(f"\nDatu tipi:")
print(df.dtypes)

# %%
# Kādi kafijas veidi ir datos?
print("Kafijas veidi:")
print(df['coffee_name'].unique())

# %% [markdown]
# ---
#
# ## ✏️ UZDEVUMS 1: Populārākie kafijas veidi
#
# Izveidojiet stabiņu diagrammu (bar chart), kas parāda, cik reizes katrs kafijas veids ir nopirkts.
#
# **Padomi:**
# - Izmantojiet `df['coffee_name'].value_counts()` lai saskaitītu ([dokumentācija](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html))
# - Izmantojiet `.plot(kind='bar')` lai uzzīmētu ([bar chart piemēri](https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_colors.html))
# <details>
# <summary>📚 Dokumentācijas references</summary>
#
# - [pandas.Series.value_counts() - vērtību saskaitīšana](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html)
# - [DataFrame.plot() - grafiku zīmēšana](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)
# - [Matplotlib stabiņu diagrammas](https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_colors.html)
# - [plt.title(), plt.xlabel(), plt.ylabel()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html)
#
# </details>
#
# <details>
# <summary>💾 Kā saglabāt grafiku</summary>
#
# Pievieno šo kodu **pirms** `plt.show()`:
#
# ```python
# import os
# from datetime import datetime
#
# os.makedirs('../my_graphs', exist_ok=True)
# timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
# plt.savefig(f'../my_graphs/{timestamp}_grafika_nosaukums.png', dpi=300, bbox_inches='tight')
# print('Grafiks saglabāts!')
# ```
#
# Aizstāj `grafika_nosaukums` ar aprakstošu vārdu, piemēram `kafijas_popularitate`.
#
# </details>

# %%
# TAVS KODS ŠEIT:
# 1. Saskaiti kafijas veidu popularitāti
# 2. Uzzīmē stabiņu diagrammu

# %% [markdown]
# <details>
# <summary> Klikšķini šeit, lai redzētu risinājumu</summary>
#
# ```python
# # Saskaitām kafijas veidu popularitāti
# coffee_counts = df['coffee_name'].value_counts()
#
# # Zīmējam stabiņu diagrammu
# coffee_counts.plot(kind='bar', color='brown')
# plt.title('Populārākie kafijas veidi')
# plt.xlabel('Kafijas veids')
# plt.ylabel('Pārdoto skaits')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
# ```
# </details>

# %% [markdown]
# ---
#
# ## ✏️ UZDEVUMS 2: Pārdošanas apjoms pa dienām
#
# Izveidojiet līniju grafiku, kas parāda, cik pirkumu notiek katrā dienā.
#
# **Padomi:**
# - Grupējiet datus pēc datuma: `df.groupby('date')` ([groupby dokumentācija](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html))
# - Saskaitiet ierakstus: `.size()`
# - Zīmējiet līniju: `.plot(kind='line')` ([line plot piemēri](https://matplotlib.org/stable/gallery/lines_bars_and_markers/simple_plot.html))
# <details>
# <summary>📚 Dokumentācijas references</summary>
#
# - [DataFrame.groupby() - datu grupēšana](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)
# - [GroupBy.size() - elementu saskaitīšana](https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.GroupBy.size.html)
# - [Matplotlib līniju grafiki](https://matplotlib.org/stable/gallery/lines_bars_and_markers/simple_plot.html)
#
# </details>
#
# <details>
# <summary>💾 Kā saglabāt grafiku</summary>
#
# Pievieno šo kodu **pirms** `plt.show()`:
#
# ```python
# import os
# from datetime import datetime
#
# os.makedirs('../my_graphs', exist_ok=True)
# timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
# plt.savefig(f'../my_graphs/{timestamp}_grafika_nosaukums.png', dpi=300, bbox_inches='tight')
# print('Grafiks saglabāts!')
# ```
#
# Aizstāj `grafika_nosaukums` ar aprakstošu vārdu, piemēram `kafijas_popularitate`.
#
# </details>

# %%
# TAVS KODS ŠEIT:
# 1. Grupē datus pēc datuma un saskaiti
# 2. Uzzīmē līniju grafiku

# %% [markdown]
# <details>
# <summary> Klikšķini šeit, lai redzētu risinājumu</summary>
#
# ```python
# # Saskaitām pirkumus katrā dienā
# daily_sales = df.groupby('date').size()
#
# # Zīmējam līniju grafiku
# daily_sales.plot(kind='line', color='green', linewidth=1)
# plt.title('Pirkumu skaits pa dienām')
# plt.xlabel('Datums')
# plt.ylabel('Pirkumu skaits')
# plt.tight_layout()
# plt.show()
# ```
# </details>

# %% [markdown]
# ---
#
# ## ✏️ UZDEVUMS 3: Ieņēmumi pa dienām
#
# Izveidojiet līniju grafiku, kas parāda kopējos ieņēmumus katrā dienā.
#
# **Padomi:**
# - Grupējiet pēc datuma un summējiet naudu: `df.groupby('date')['money'].sum()`
# <details>
# <summary>📚 Dokumentācijas references</summary>
#
# - [DataFrame.groupby() - datu grupēšana](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)
# - [GroupBy.sum() - summas aprēķins](https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.GroupBy.sum.html)
# - [Matplotlib līniju grafiki](https://matplotlib.org/stable/gallery/lines_bars_and_markers/simple_plot.html)
#
# </details>
#
# <details>
# <summary>💾 Kā saglabāt grafiku</summary>
#
# Pievieno šo kodu **pirms** `plt.show()`:
#
# ```python
# import os
# from datetime import datetime
#
# os.makedirs('../my_graphs', exist_ok=True)
# timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
# plt.savefig(f'../my_graphs/{timestamp}_grafika_nosaukums.png', dpi=300, bbox_inches='tight')
# print('Grafiks saglabāts!')
# ```
#
# Aizstāj `grafika_nosaukums` ar aprakstošu vārdu, piemēram `kafijas_popularitate`.
#
# </details>

# %%
# TAVS KODS ŠEIT:

# %% [markdown]
# <details>
# <summary> Klikšķini šeit, lai redzētu risinājumu</summary>
#
# ```python
# # Saskaitām ieņēmumus katrā dienā
# daily_revenue = df.groupby('date')['money'].sum()
#
# # Zīmējam līniju grafiku
# daily_revenue.plot(kind='line', color='blue', linewidth=1)
# plt.title('Ieņēmumi pa dienām')
# plt.xlabel('Datums')
# plt.ylabel('Ieņēmumi (EUR)')
# plt.tight_layout()
# plt.show()
# ```
# </details>

# %% [markdown]
# ---
#
# ## ✏️ UZDEVUMS 4: Apaļā diagramma (Pie Chart)
#
# Izveidojiet apaļo diagrammu, kas parāda maksājumu veidu (card vs cash) proporcijas.
#
# **Padomi:**
# - Saskaitiet `cash_type` kolonnas vērtības
# - Izmantojiet `plot(kind='pie')` ([pie chart piemēri](https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html))
# <details>
# <summary>📚 Dokumentācijas references</summary>
#
# - [pandas.Series.value_counts() - vērtību saskaitīšana](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html)
# - [Matplotlib sektoru diagrammas (pie)](https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html)
# - [plot(kind="pie") parametri](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.pie.html)
#
# </details>
#
# <details>
# <summary>💾 Kā saglabāt grafiku</summary>
#
# Pievieno šo kodu **pirms** `plt.show()`:
#
# ```python
# import os
# from datetime import datetime
#
# os.makedirs('../my_graphs', exist_ok=True)
# timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
# plt.savefig(f'../my_graphs/{timestamp}_grafika_nosaukums.png', dpi=300, bbox_inches='tight')
# print('Grafiks saglabāts!')
# ```
#
# Aizstāj `grafika_nosaukums` ar aprakstošu vārdu, piemēram `kafijas_popularitate`.
#
# </details>

# %%
# TAVS KODS ŠEIT:

# %% [markdown]
# <details>
# <summary> Klikšķini šeit, lai redzētu risinājumu</summary>
#
# ```python
# # Saskaitām maksājumu veidus
# payment_types = df['cash_type'].value_counts()
#
# # Zīmējam apaļo diagrammu
# payment_types.plot(kind='pie', autopct='%1.1f%%', colors=['#3498db', '#2ecc71'])
# plt.title('Maksājumu veidu proporcijas')
# plt.ylabel('')
# plt.show()
# ```
# </details>

# %% [markdown]
# ---
#
# #  Apsveicam!
#
# Tu esi pabeidzis 1. daļu! Tagad tu proti:
# - Ielādēt CSV datus ar pandas
# - Analizēt datu struktūru
# - Veidot stabiņu, līniju un apaļās diagrammas
#
# ### 🔗 Turpmākai izpētei
# - [Pandas Cheat Sheet (PDF)](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# - [Matplotlib Cheat Sheet](https://matplotlib.org/cheatsheets/)
# - [Kaggle - datu zinātnes kursi](https://www.kaggle.com/learn)
#
# **Turpini ar 2. daļu, lai iemācītos par tendenču līnijām un prognozēšanu!**

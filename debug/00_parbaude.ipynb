# %% [markdown]
# #  00 - Sistēmas Pārbaude
#
# **Laiks:** 2-3 minūtes
# **Mērķis:** Pārliecināties, ka viss darbojas pirms sākam galveno darbu
#
# ---
#
# ## [OK] Uzdevums 1: Pārbaudi Python
#
# Palaid šo šūnu. Ja redzat rezultātu, Python darbojas!

# %%
print("[OK] Sveika, pasaule!")
print(f"[OK] Python darbojas!")

# Matemātika
rezultats = 2 + 2
print(f"[OK] 2 + 2 = {rezultats}")

# %% [markdown]
# ---
#
# ## �� Grafiku Saglabāšana / Saving Graphs
#
# **Lai saglabātu jebkuru grafiku**, pievieno šo kodu **PIRMS** `plt.show()`:`
#
# `python
# # Saglabā grafiku / Save the graph
# from datetime import datetime
# import os
#
# os.makedirs('../my_graphs', exist_ok=True)
# timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
# plt.savefig(f'../my_graphs/{timestamp}_test_graph.png', dpi=300, bbox_inches='tight')
# print(f'✅ Grafiks saglabāts!')
# `python
#
# **Pilnu dokumentāciju skatīt:** `GRAPH_SAVING_SNIPPET.md`
#
# ---

# %% [markdown]
# ---
#
# ## [OK] Uzdevums 2: Pārbaudi Pandas
#
# Pārbaudīsim, vai pandas bibliotēka ir instalēta.

# %%
import pandas as pd

print(f"[OK] Pandas versija: {pd.__version__}")
print("[OK] Pandas darbojas!")

# %% [markdown]
# ---
#
# ## [OK] Uzdevums 3: Pārbaudi Matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt

print(f"[OK] Matplotlib versija: {matplotlib.__version__}")
print("[OK] Matplotlib darbojas!")

# %% [markdown]
# ---
#
# ## [OK] Uzdevums 4: Pārbaudi Datu Failu

# %%
import os

data_file = '../data/coffee_sales/index_1.csv'

if os.path.exists(data_file):
    print(f"[OK] Datu fails atrasts: {data_file}")
    
    # Ielādējam datus
    df = pd.read_csv(data_file)
    print(f"[OK] Dati ielādēti! Rindu skaits: {len(df)}")
    print(f"[OK] Kolonnas: {df.columns.tolist()}")
else:
    print(f"[ERROR] Datu fails NAV atrasts: {data_file}")
    print("Pārbaudi, vai esi pareizajā mapē!")

# %% [markdown]
# ---
#
# ## [OK] Uzdevums 5: Vienkāršs Grafiks

# %%
# Vienkārši testa dati
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.figure(figsize=(6, 4))
plt.plot(x, y, 'o-', color='green', linewidth=2, markersize=8)
plt.title('[OK] Grafiks Darbojas!', fontsize=14, fontweight='bold')
plt.xlabel('X ass')
plt.ylabel('Y ass')
plt.grid(True, alpha=0.3)
plt.show()

print("[OK] Grafiks parādījās! Viss darbojas!")

# %% [markdown]
# ---
#
# ##  Pārbaude Pabeigta!
#
# Ja visi uzdevumi parādīja [OK], tad:
#
# [OK] Python darbojas
# [OK] Pandas darbojas
# [OK] Matplotlib darbojas
# [OK] Dati ir pieejami
# [OK] Grafiki darbojas
#
# **Tu esi gatavs/a sākt!**
#
# ### Nākamais Solis:
# Atver: `01_pamata_vizualizacija.ipynb`
#
# ---
#
# ## [ERROR] Ja Kaut Kas Nedarbojas
#
# **Kļūda:** `ModuleNotFoundError`
# **Risinājums:** Izpildi `setup.bat` vēlreiz
#
# **Kļūda:** `FileNotFoundError`
# **Risinājums:** Pārbaudi, vai esi pareizajā mapē (ar `data/` apakšmapi)
#
# **Citas problēmas:**
# Celiet roku un pajautājiet skolotājam! 🙋‍♂️🙋‍♀️
